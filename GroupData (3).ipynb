# %% [markdown]
# Introduction:

# %% [markdown]
# For This project, we decided to approach the search for the "best" neighborhood in Pittsburgh with the primary metric being focused on what neighborhood is most fun. We first had to determine what fun meant and to what group of people. Due to our ages and definitions of fun we decided to look into neighborhood demographics, recreation, and safety. Initially we were thinking of using 3 different examples of neighborhood recreation to measure fun but decided that fun means things outside of entertainment being available to create a holistically positive environment.

# %% [markdown]
# The Metric:

# %% [markdown]
# To do this, our submetrics consisted of general demographic information to first see where the most young-adults lived. Next we looked at geographical data based on how many restaurants are in one given region to measure the levels of recreation within neighborhoods and finally measured crime rates to determine the safety of neighborhoods in Pittsburgh. The most important aspects of our data sets were that they represented data specific to individual neighborhoods within Pittsburgh. Without the mention of specific neighborhoods there would be no way to narrow our search to see where our submetrics overlap in order to come to a consensus about what neighborhood was the best.

# %% [markdown]
# ## The Best Neighborhood:

# %% [markdown]
# ## Safety:

# %% [markdown]
# Average Crime Rates:

# %% [markdown]
# ![image.png](attachment:2bda4938-d276-4852-af56-3b2b26627601.png)

# %% [markdown]
# Crime Rates by population:

# %% [markdown]
# ![image.png](attachment:48b8f428-79c6-4c5b-abc1-912ce1b4640c.png)

# %% [markdown]
# Crime Conclusion:

# %% [markdown]
# The final list of the most fun neighborhoods in Pittsburgh, analyzed by crime rate is:
#
# Central Oakland
# North Oakland
# South Oakland
# The Strip District

# %% [markdown]
# ## Demographics:

# %%
import pandas as pd
data = pd.read_csv("households.csv")
data['Single_household_total_ratio'] = data['Estimate; Nonfamily households: - Householder living alone'] / data['Estimate; Total:']
data.head(10)
# Out:
#         Neighborhood  Id  Estimate; Total:  Margin of Error; Total:  \
# 0   Allegheny Center   1             870.0                93.000000
# 1     Allegheny West   2             146.0                36.000000
# 2          Allentown   3            1069.0               132.457540
# 3          Arlington   4             701.0               104.465305
# 4  Arlington Heights   5             144.0                59.000000
# 5         Banksville   6            1946.0               229.222599
# 6  Bedford Dwellings   7             723.0                53.000000
# 7          Beechview   8            3567.0               258.027130
# 8        Beltzhoover   9             848.0               156.057682
# 9         Bloomfield  10            4571.0               205.494525
#
#    Estimate; Family households:  Margin of Error; Family households:  \
# 0                         184.0                            59.000000
# 1                          70.0                            32.000000
# ...

# %% [markdown]
# ![image.png](attachment:498861d7-f305-4180-a9d8-0f4cf466a5cb.png)

# %% [markdown]
# Demographic conclusion:

# %% [markdown]
# The Strip District has the most single non-family member households. We are using this data to interpret where the most "fun friendly" neighborhoods are which in this case we are considering to be those with the most young adults. So our data suggests that this neighborhood is the Strip District which makes sense because of how trendy and business savvy it is.

# %% [markdown]
# ## Recreation: Restaurants

# %% [markdown]
# ![image.png](attachment:d9ef91d4-9b28-4885-be6d-aad5f674df33.png)

# %% [markdown]
# ![image.png](attachment:9ccbb971-ed01-4c06-8568-d1b9419d2b2f.png)

# %% [markdown]
# Recreation Conclusion:

# %% [markdown]
# Resturants are most abundent in North Shore and Central Business District. This is by a long shot. The majority of other neighborhoods don't come close after the Central Business District. This could have to do with the overall atmosephere of the neighborhood and the household demographics associated to these neighborhoods.

# %% [markdown]
# ## Group Conlusions:

# %% [markdown]
# These were interesting data sets to look at from the approach of what neighborhood is most holistically fun. The metrics we used were specifically chosen based on our definitions of fun and what conditions we think, collectively, contribute to a positive enivronment for people our age. Although not every data set pointed to the same neighborhood, we concluded that the most fun neighborhood was the Strip District. If looking at just household and recreation, the Central Business district could have won however their lack of safety was too much of an outlier based on our data to agree that that is the most safe.

# %% [markdown]
# ### Personal Favorites:

# %% [markdown]
# #### Tara:

# %% [markdown]
# While I have only been in Pittsburgh for as long as I've been to school here, I believe the best neighborhoods are either ShadySide or South Side. They have a lot of good restaruants and recreation while being easily accesible by us Pitt students. They also have a lot to do outside of just for people our age so they're great for an all encompassing good environment.

# %% [markdown]
# #### Karina:

# %% [markdown]
# I have also not been in Pittsburgh for a long time now but I think my favorite neighborhood is Shadyside. I think it is the best also because of its restaruants as well as it's accessibility for students. There are also a lot of great neighborhoods surrounding Shadyside that feels like home. Also they have a lot of stores that are hard to find elsewhere around here so it is very efficient for things mist college students will need.

# %% [markdown]
# #### Alyssa:

# %% [markdown]
# My favorite neighborhood is Lawrenceville, especially because of Butler Street. I like the ease of access to the various stores and places to go on the main street, which is also similar to the Strip. The vibes of the area seem very similar, and it would be.a place that could notmally go to hangout with friends. While my favorite varies with out conclsuion our data brought us to, these neighborhoods are still very similar and overall gr.
